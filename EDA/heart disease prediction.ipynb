# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\haris\Downloads\cleaned_merged_heart_dataset.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 0   63    1   3       145   233    1        0       150      0      2.3
# 1   37    1   2       130   250    0        1       187      0      3.5
# 2   41    0   1       130   204    0        0       172      0      1.4
# 3   56    1   1       120   236    0        1       178      0      0.8
# 4   57    0   0       120   354    0        1       163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 1883   60    1   0       140   207    0        0       138      1      1.9
# 1884   46    1   0       140   311    0        1       120      1      1.8
# 1885   59    1   3       134   204    0        1       162      0      0.8
# 1886   54    1   1       154   232    0        0       164      0      0.0
# 1887   53    1   0       110   335    0        1       143      1      3.0
#
#       slope  ca  thal  target
# 1883      2   1     3       0
# 1884      1   2     3       0
# 1885      2   2     2       0
# 1886      2   1     2       0
# 1887      1   1     3       0

# %%
df.sample()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 734   65    0   0       150   225    0        0       114      0      1.0
#
#      slope  ca  thal  target
# 734      1   3     3       0

# %%
df.shape
# Out:
# (1888, 14)

# %%
df.size
# Out:
# 26432

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1888, step=1)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1888 entries, 0 to 1887
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1888 non-null   int64
#  1   sex       1888 non-null   int64
#  2   cp        1888 non-null   int64
#  3   trestbps  1888 non-null   int64
#  4   chol      1888 non-null   int64
#  5   fbs       1888 non-null   int64
#  6   restecg   1888 non-null   int64
#  7   thalachh  1888 non-null   int64
#  8   exang     1888 non-null   int64
#  9   oldpeak   1888 non-null   float64
#  10  slope     1888 non-null   int64
#  11  ca        1888 non-null   int64
#  12  thal      1888 non-null   int64
#  13  target    1888 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 206.6 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1888.000000  1888.000000  1888.000000  1888.000000  1888.000000
# mean     54.354343     0.688559     1.135593   131.549258   246.855403
# std       9.081505     0.463205     1.103852    17.556985    51.609329
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      47.750000     0.000000     0.000000   120.000000   211.000000
# 50%      55.000000     1.000000     1.000000   130.000000   241.000000
# 75%      61.000000     1.000000     2.000000   140.000000   276.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg     thalachh        exang      oldpeak  \
# count  1888.000000  1888.000000  1888.000000  1888.000000  1888.000000
# mean      0.148305     0.597458   149.424258     0.331568     1.053761
# std       0.355496     0.638820    23.006153     0.470901     1.161344
# ...

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalachh    False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df["age"]
# Out:
# 0       63
# 1       37
# 2       41
# 3       56
# 4       57
#         ..
# 1883    60
# 1884    46
# 1885    59
# 1886    54
# 1887    53
# Name: age, Length: 1888, dtype: int64

# %%
df[["age","sex","slope"]]
# Out:
#       age  sex  slope
# 0      63    1      0
# 1      37    1      0
# 2      41    0      2
# 3      56    1      2
# 4      57    0      2
# ...   ...  ...    ...
# 1883   60    1      2
# 1884   46    1      1
# 1885   59    1      2
# 1886   54    1      2
# 1887   53    1      1
#
# [1888 rows x 3 columns]

# %%
df.loc[1:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 1   37    1   2       130   250    0        1       187      0      3.5
# 2   41    0   1       130   204    0        0       172      0      1.4
# 3   56    1   1       120   236    0        1       178      0      0.8
# 4   57    0   0       120   354    0        1       163      1      0.6
# 5   57    1   0       140   192    0        1       148      0      0.4
#
#    slope  ca  thal  target
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1
# 5      1   0     1       1

# %%
df.loc[1:5,["age","chol"]]
# Out:
#    age  chol
# 1   37   250
# 2   41   204
# 3   56   236
# 4   57   354
# 5   57   192

# %%
df.iloc[0:5,[7]]
# Out:
#    thalachh
# 0       150
# 1       187
# 2       172
# 3       178
# 4       163

# %%
df.sort_values("age")
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 72     29    1   1       130   204    0        0       202      0      0.0
# 421    29    1   1       130   204    0        0       202      0      0.0
# 1543   29    1   1       130   204    0        2       202      0      0.0
# 367    29    1   1       130   204    0        0       202      0      0.0
# 971    29    1   1       130   204    0        0       202      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...       ...    ...      ...
# 238    77    1   0       125   304    0        0       162      1      0.0
# 1837   77    0   0       125   304    0        0       162      1      0.0
# 463    77    1   0       125   304    0        0       162      1      0.0
# 465    77    1   0       125   304    0        0       162      1      0.0
# 1528   77    1   3       125   304    0        2       162      1      0.0
#
#       slope  ca  thal  target
# 72        2   0     2       1
# ...

# %%
df.sort_values("age",ascending=False)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalachh  exang  oldpeak  \
# 690    77    1   0       125   304    0        0       162      1      0.0
# 1837   77    0   0       125   304    0        0       162      1      0.0
# 463    77    1   0       125   304    0        0       162      1      0.0
# 465    77    1   0       125   304    0        0       162      1      0.0
# 1528   77    1   3       125   304    0        2       162      1      0.0
# ...   ...  ...  ..       ...   ...  ...      ...       ...    ...      ...
# 367    29    1   1       130   204    0        0       202      0      0.0
# 971    29    1   1       130   204    0        0       202      0      0.0
# 1671   29    1   1       130   204    0        0       202      0      0.0
# 72     29    1   1       130   204    0        0       202      0      0.0
# 421    29    1   1       130   204    0        0       202      0      0.0
#
#       slope  ca  thal  target
# 690       2   3     2       0
# ...

# %%
df.groupby("sex").agg({"chol":["min","max","mean"],"trestbps":["min","max","mean"]})
# Out:
#     chol                  trestbps
#      min  max        mean      min  max        mean
# sex
# 0    141  564  262.113946       94  200  133.341837
# 1    126  407  239.953846       94  192  130.738462

# %%
pd.pivot_table(data=df,values="chol",index="sex",columns="exang",aggfunc=["mean","min","max","median"])
# Out:
#              mean              min       max      median
# exang           0           1    0    1    0    1      0      1
# sex
# 0      258.011038  275.881481  141  177  564  409  252.0  269.0
# 1      236.442522  245.739308  126  131  407  353  233.0  246.0

# %%
sns.histplot(data=df,x="age",kde=True,bins=30,hue="sex")
plt.show()

# %%
sns.scatterplot(data=df,x="chol",y="trestbps",hue="sex")
plt.show()

# %%
sns.countplot(data=df,x="sex")
plt.show()

# %%
plt.figure(figsize=(13,6))
corr=df.corr(numeric_only=True)
sns.heatmap(data=corr,annot=True,cmap="Set3")
plt.show()

# %%
sns.pairplot(df[["trestbps","chol","thalachh","oldpeak","sex"]],hue="sex")
plt.show()

# %%
sns.boxplot(data=df, x="target", y="age")
plt.title("Age vs Heart Disease")
plt.show()

# %%
sns.violinplot(data=df, x="target", y="trestbps")
plt.title("Resting Blood Pressure vs Heart Disease")
plt.show()
